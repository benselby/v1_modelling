# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import numpy as np

# %matplotlib inline

# %%
# img = mpimg.imread('stinkbug.png')
img = mpimg.imread('v1-topology-blasdel-figure6.png')

plt.imshow(img)

print np.shape(img)
print img
print np.max(img), np.min(img), np.mean(img)
# Out:
# (295L, 394L, 3L)
# [[[ 0.74117649  0.7647059   0.47058824]
#   [ 0.86274511  0.76078433  0.41176471]
#   [ 0.90980393  0.71764708  0.3764706 ]
#   ...,
#   [ 0.69411767  0.20392157  0.3137255 ]
#   [ 0.67843139  0.20392157  0.32156864]
#   [ 0.67450982  0.21960784  0.32941177]]
#
#  [[ 0.65882355  0.76078433  0.45490196]
#   [ 0.75686276  0.7647059   0.42352942]
#   [ 0.84705883  0.77254903  0.40392157]
#   ...,
#   [ 0.66666669  0.20784314  0.33333334]
#   [ 0.66666669  0.19607843  0.32941177]
#   [ 0.65882355  0.21960784  0.34901962]]
#
#  [[ 0.56862748  0.72156864  0.4509804 ]
#   [ 0.60784316  0.72156864  0.42352942]
#   [ 0.69803923  0.7647059   0.40392157]
#   ...,
#   [ 0.627451    0.1882353   0.30980393]
#   [ 0.64705884  0.19607843  0.32941177]
#   [ 0.63137257  0.2         0.34117648]]
#
#  ...,
#  [[ 0.84705883  0.80000001  0.39215687]
#   [ 0.8392157   0.80000001  0.37254903]
#   [ 0.80392158  0.78039217  0.38039216]
#   ...,
#   [ 0.97254902  0.81960785  0.3764706 ]
# ...
