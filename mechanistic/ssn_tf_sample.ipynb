# %%
import ssn_subpop_tf as ssn
import matplotlib.pyplot as plt
import numpy as np
import time

reload(ssn)

# %matplotlib inline

# %%
# Generate the network:
st = time.time()
ss_net = ssn.SSNetwork(subpop=False)
print "Time to generate network: ", time.time()-st
# Out:
# Generating an SSN with grid size 75 over 16.0 degrees.
# Instantiating a SSN without ocular domiance map.
# Time to generate network:  15.5454540253

# %%
c = 20
yi = 37
xi = 37
dx = ss_net.dx
hx = ssn.generate_mono_stimulus(ss_net.OP_map[yi,xi], 1, [xi*dx, yi*dx], ss_net.OP_map, full_frame=True )

plt.imshow(hx)
plt.colorbar()
plt.title("Full frame input")
# Out:
# /Users/mollybeckel/anaconda/lib/python2.7/site-packages/matplotlib/collections.py:590: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if self._edgecolors == str('face'):

# %%
# Run Tensorflow simulation:
st = time.time()
rE, rI = ss_net.run_tf_simulation(20., hx.astype(np.float32))
print "Time elapsed for TensorFlow classic simulation: ", time.time()-st
# Out:
# Time elapsed for TensorFlow classic simulation:  122.344765186

# %%
plt.figure()
plt.imshow(rE[0])
plt.title('E unit steady-state (t=500ms)')
plt.colorbar()

plt.figure()
plt.imshow(rI[0])
plt.title('I unit steady-state (t=500ms)')
plt.colorbar()
# Out:
# <matplotlib.colorbar.Colorbar instance at 0x10ee755f0>
